# %%
from PIL import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
from torchvision import transforms
from torch.autograd import Variable
import torch.optim as optim
import pickle
import os
import re

# %%
with open ("colors.pkl",'rb') as f:
    colors = pickle.load(f)

# %%
colors.add('orange')
colors.add('grey')
colors.add('dark')
colors.add('bright')
colors.add('brown')

# %%
colors_re = re.compile('|'.join(map(re.escape, colors)))

# %%
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(256),
    transforms.ToTensor()
])

# %%
titles = []
images = []
txts = []

# %%
input_rootdir = 'data/birds/CUB_200_2011/graysclae_image'
input_text = 'data/birds/text'
cnt = 0
for subfolder in os.listdir(input_rootdir):
    if subfolder == '.DS_Store':
        continue
    img_ls = os.listdir(input_rootdir+'/' + subfolder)
    if img_ls == '.DS_Store':
        continue
    for img_name in img_ls:
        if img_name == '.DS_Store':
            continue
        img = Image.open(input_rootdir+ '/' + subfolder +'/' + img_name)
        img_tensor = preprocess(img).squeeze(0)
        with open (input_text + '/' + subfolder + '/' + img_name[:-4] + '.txt') as f:
            txt = f.read().replace('\n', '')
            txt = colors_re.sub("", txt)
        titles.append(img_name[:-4])
        images.append(img_tensor)
        txts.append(txt)
        cnt += 1
    print(input_rootdir+ '/' + subfolder , '***', cnt)
    cnt = 0
# Out:
# data/birds/CUB_200_2011/graysclae_image/005.Crested_Auklet *** 44
# data/birds/CUB_200_2011/graysclae_image/015.Lazuli_Bunting *** 58
# data/birds/CUB_200_2011/graysclae_image/156.White_eyed_Vireo *** 60
# data/birds/CUB_200_2011/graysclae_image/081.Pied_Kingfisher *** 60
# data/birds/CUB_200_2011/graysclae_image/135.Bank_Swallow *** 59
# data/birds/CUB_200_2011/graysclae_image/200.Common_Yellowthroat *** 60
# data/birds/CUB_200_2011/graysclae_image/086.Pacific_Loon *** 60
# data/birds/CUB_200_2011/graysclae_image/067.Anna_Hummingbird *** 60
# data/birds/CUB_200_2011/graysclae_image/076.Dark_eyed_Junco *** 60
# data/birds/CUB_200_2011/graysclae_image/149.Brown_Thrasher *** 59
# data/birds/CUB_200_2011/graysclae_image/127.Savannah_Sparrow *** 60
# data/birds/CUB_200_2011/graysclae_image/041.Scissor_tailed_Flycatcher *** 60
# data/birds/CUB_200_2011/graysclae_image/141.Artic_Tern *** 58
# data/birds/CUB_200_2011/graysclae_image/082.Ringed_Kingfisher *** 60
# data/birds/CUB_200_2011/graysclae_image/099.Ovenbird *** 60
# data/birds/CUB_200_2011/graysclae_image/013.Bobolink *** 60
# data/birds/CUB_200_2011/graysclae_image/104.American_Pipit *** 60
# data/birds/CUB_200_2011/graysclae_image/023.Brandt_Cormorant *** 59
# data/birds/CUB_200_2011/graysclae_image/168.Kentucky_Warbler *** 59
# data/birds/CUB_200_2011/graysclae_image/072.Pomarine_Jaeger *** 60
# data/birds/CUB_200_2011/graysclae_image/040.Olive_sided_Flycatcher *** 60
# data/birds/CUB_200_2011/graysclae_image/185.Bohemian_Waxwing *** 60
# data/birds/CUB_200_2011/graysclae_image/144.Common_Tern *** 60
# data/birds/CUB_200_2011/graysclae_image/034.Gray_crowned_Rosy_Finch *** 59
# data/birds/CUB_200_2011/graysclae_image/126.Nelson_Sharp_tailed_Sparrow *** 59
# data/birds/CUB_200_2011/graysclae_image/163.Cape_May_Warbler *** 60
# data/birds/CUB_200_2011/graysclae_image
# data/birds/CUB_200_2011/graysclae_image/179.Tennessee_Warbler *** 59
# data/birds/CUB_200_2011/graysclae_image/036.Northern_Flicker *** 60
# data/birds/CUB_200_2011/graysclae_image/008.Rhinoceros_Auklet *** 48
# data/birds/CUB_200_2011/graysclae_image/097.Orchard_Oriole *** 59
# data/birds/CUB_200_2011/graysclae_image/095.Baltimore_Oriole *** 60
# data/birds/CUB_200_2011/graysclae_image/032.Mangrove_Cuckoo *** 53
# data/birds/CUB_200_2011/graysclae_image/151.Black_capped_Vireo *** 51
# data/birds/CUB_200_2011/graysclae_image/037.Acadian_Flycatcher *** 59
# data/birds/CUB_200_2011/graysclae_image/044.Frigatebird *** 60
# data/birds/CUB_200_2011/graysclae_image/193.Bewick_Wren *** 60
# data/birds/CUB_200_2011/graysclae_image/125.Lincoln_Sparrow *** 59
# data/birds/CUB_200_2011/graysclae_image/170.Mourning_Warbler *** 60
# data/birds/CUB_200_2011/graysclae_image/172.Nashville_Warbler *** 60
# data/birds/CUB_200_2011/graysclae_image/073.Blue_Jay *** 60
# data/birds/CUB_200_2011/graysclae_image/138.Tree_Swallow *** 60
# data/birds/CUB_200_2011/graysclae_image/132.White_crowned_Sparrow *** 60
# data/birds/CUB_200_2011/graysclae_image/198.Rock_Wren *** 60
# data/birds/CUB_200_2011/graysclae_image/124.Le_Conte_Sparrow *** 59
# data/birds/CUB_200_2011/graysclae_image/199.Winter_Wren *** 60
# data/birds/CUB_200_2011/graysclae_image/003.Sooty_Albatross *** 58
# data/birds/CUB_200_2011/graysclae_image/085.Horned_Lark *** 60
# data/birds/CUB_200_2011/graysclae_image/142.Black_Tern *** 60
# data/birds/CUB_200_2011/graysclae_image/181.Worm_eating_Warbler *** 59
# data/birds/CUB_200_2011/graysclae_image/068.Ruby_throated_Hummingbird *** 60
# data/birds/CUB_200_2011/graysclae_image/112.Great_Grey_Shrike *** 60
# data/birds/CUB_200_2011/graysclae_image/028.Brown_Creeper *** 59
# data/birds/CUB_200_2011/graysclae_image/018.Spotted_Catbird *** 45
# data/birds/CUB_200_2011/graysclae_image/087.Mallard *** 60
# data/birds/CUB_200_2011/graysclae_image/051.Horned_Grebe *** 60
# data/birds/CUB_200_2011/graysclae_image/007.Parakeet_Auklet *** 53
# data/birds/CUB_200_2011/graysclae_image/039.Least_Flycatcher *** 59
# data/birds/CUB_200_2011/graysclae_image/020.Yellow_breasted_Chat *** 59
# data/birds/CUB_200_2011/graysclae_image/113.Baird_Sparrow *** 50
# data/birds/CUB_200_2011/graysclae_image/194.Cactus_Wren *** 60
# data/birds/CUB_200_2011/graysclae_image/061.Heermann_Gull *** 60
# data/birds/CUB_200_2011/graysclae_image/175.Pine_Warbler *** 60
# data/birds/CUB_200_2011/graysclae_image/046.Gadwall *** 60
# data/birds/CUB_200_2011/graysclae_image/054.Blue_Grosbeak *** 60

# %%
with open('title.pkl','wb') as f:
    pickle.dump(titles,f)

# %%
images_tensors = torch.tensor(images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-8b5d314e42bd> in <module>
# ----> 1 images_tensors = torch.tensor(images)
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
with open('img.pkl','wb') as f:
    pickle.dump(images,f)
